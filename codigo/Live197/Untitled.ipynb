# %%
def formatação(quem, prog, n):
    from IPython.core.debugger import set_trace
    return '{quem} está apresentando a {prog} #{n}'


nome = 'Eduardo'
programa = 'Live de Python'
numero = '197'

breakpoint()

formatado = formatação(nome, programa, numero)
# Out:
# > /tmp/ipykernel_77690/761188316.py(3)formatação()
#       1 def formatação(quem, prog, n):
#       2     import pdb;pdb.set_trace()
# ----> 3     return '{quem} está apresentando a {prog} #{n}'
#       4
#       5
#
# ipdb> l
#       1 def formatação(quem, prog, n):
#       2     import pdb;pdb.set_trace()
# ----> 3     return '{quem} está apresentando a {prog} #{n}'
#       4
#       5
#       6 nome = 'Eduardo'
#       7 programa = 'Live de Python'
#       8 numero = '197'
#       9
#      10 breakpoint()
#      11
#
# ipdb> quem
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb>
# 'Eduardo'
# ipdb> w
#     [... skipping 21 hidden frame(s)]
#
#   /tmp/ipykernel_77690/761188316.py(12)<cell line: 12>()
#       8 numero = '197'
#       9
#      10 breakpoint()
#      11
# ---> 12 formatado = formatação(nome, programa, numero)
#
# > /tmp/ipykernel_77690/761188316.py(3)formatação()
#       1 def formatação(quem, prog, n):
#       2     import pdb;pdb.set_trace()
# ----> 3     return '{quem} está apresentando a {prog} #{n}'
#       4
#       5
#
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# Input In [7], in <cell line: 12>()
#       8 numero = '197'
#      10 breakpoint()
# ---> 12 formatado = formatação(nome, programa, numero)
#
# Input In [7], in formatação(quem, prog, n)
#       1 def formatação(quem, prog, n):
#       2     import pdb;pdb.set_trace()
# ----> 3     return '{quem} está apresentando a {prog} #{n}'
#
# Input In [7], in formatação(quem, prog, n)
#       1 def formatação(quem, prog, n):
#       2     import pdb;pdb.set_trace()
# ----> 3     return '{quem} está apresentando a {prog} #{n}'
#
# File /usr/lib/python3.10/bdb.py:90, in Bdb.trace_dispatch(self, frame, event, arg)
#      88     return # None
#      89 if event == 'line':
# ---> 90     return self.dispatch_line(frame)
#      91 if event == 'call':
#      92     return self.dispatch_call(frame, arg)
#
# File /usr/lib/python3.10/bdb.py:115, in Bdb.dispatch_line(self, frame)
#     113 if self.stop_here(frame) or self.break_here(frame):
#     114     self.user_line(frame)
# --> 115     if self.quitting: raise BdbQuit
#     116 return self.trace_dispatch
#
# BdbQuit:
