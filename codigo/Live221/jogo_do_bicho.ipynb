# %% [markdown]
# # Relações do jogo do bicho
#
# ![](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.gANbKRY9lylp2z_pQtueowHaF7%26pid%3DApi&f=1&ipt=9ebc360ae28ff64be7557725a38d90cca82ea51748cc076b536e7f6eef9ba78a&ipo=images)

# %%
relacao_g = {
    'Avestruz': 1,
    'Águia': 2,
    'Burro': 3,
    'Borboleta': 4,
    'Cachorro': 5,
    'Cabra': 6,
    'Carneiro': 7,
    'Camelo': 8,
    'Cobra': 9,
    'Coelho': 10,
    'Cavalo': 11,
    'Elefante': 12,
    'Galo': 13,
    'Gato': 14,
    'Jacaré': 15,
    'Leão': 16,
    'Macaco': 17,
    'Porco': 18,
    'Pavão': 19,
    'Peru': 20,
    'Touro': 21,
    'Tigre': 22,
    'Urso': 23,
    'Veado': 24,
    'Vaca': 25
}


relacao_n = {
    1: 'Avestruz',
    2: 'Avestruz',
    3: 'Avestruz',
    4: 'Avestruz',
    5: 'Águia',
    6: 'Águia',
    7: 'Águia',
    8: 'Águia',
    9: 'Burro',
    10: 'Burro',
    11: 'Burro',
    12: 'Burro',
    13: 'Borboleta',
    14: 'Borboleta',
    15: 'Borboleta',
    16: 'Borboleta',
    17: 'Cachorro',
    18: 'Cachorro',
    19: 'Cachorro',
    20: 'Cachorro',
    21: 'Cabra',
    22: 'Cabra',
    23: 'Cabra',
    24: 'Cabra',
    25: 'Carneiro',
    26: 'Carneiro',
    27: 'Carneiro',
    28: 'Carneiro',
    29: 'Camelo',
    30: 'Camelo',
    31: 'Camelo',
    32: 'Camelo',
    33: 'Cobra',
    34: 'Cobra',
    35: 'Cobra',
    36: 'Cobra',
    37: 'Coelho',
    38: 'Coelho',
    39: 'Coelho',
    40: 'Coelho',
    41: 'Cavalo',
    42: 'Cavalo',
    43: 'Cavalo',
    44: 'Cavalo',
    44: 'Cavalo',  
    45: 'Elefante',
    46: 'Elefante',
    47: 'Elefante',
    48: 'Elefante',
    49: 'Galo',
    50: 'Galo',
    51: 'Galo',
    52: 'Galo',
    53: 'Gato',
    54: 'Gato',
    55: 'Gato',
    56: 'Gato',
    57: 'Jacaré',
    58: 'Jacaré',
    59: 'Jacaré',
    60: 'Jacaré',
    61: 'Leão',
    62: 'Leão',
    63: 'Leão',
    64: 'Leão',
    65: 'Macaco',
    66: 'Macaco',
    67: 'Macaco',
    68: 'Macaco',
    69: 'Porco',
    70: 'Porco',
    71: 'Porco',
    72: 'Porco',
    73: 'Pavão',
    74: 'Pavão',
    75: 'Pavão',
    76: 'Pavão',
    77: 'Peru',
    78: 'Peru',
    79: 'Peru',
    80: 'Peru',
    81: 'Touro',
    82: 'Touro',
    83: 'Touro',
    84: 'Touro',
    85: 'Tigre',
    86: 'Tigre',
    87: 'Tigre',
    88: 'Tigre',
    89: 'Urso',
    90: 'Urso',
    91: 'Urso',
    92: 'Urso',
    93: 'Veado',
    94: 'Veado',
    95: 'Veado',
    96: 'Veado',
    97: 'Vaca',
    98: 'Vaca',
    99: 'Vaca',
    0: 'Vaca',
}

# %%
from pandas import read_csv

df = read_csv('resultados_numeros_data.csv')

# %%
df
# Out:
#            data  milhar
# 0    2022-09-24    8982
# 1    2022-09-23    6690
# 2    2022-09-22    8679
# 3    2022-09-21    5613
# 4    2022-09-20    6680
# ..          ...     ...
# 242  2021-08-12    5452
# 243  2021-07-12     290
# 244  2021-06-12    1121
# 245  2021-04-12    1929
# 246  2021-03-12    3945
#
# [247 rows x 2 columns]

# %%
from pandas import Series

grupos = Series(relacao_g)

numeros = Series(relacao_n)

# %%
def numero_animal(n, numeros=numeros):
    return numeros.loc[n]
    
def grupo_animal(animal, grupos=grupos):
    return grupos.loc[animal]

grupo_animal(numero_animal(74))
# Out:
# 19

# %%
df.index = df.data
del df['data']

# %%
df['resultado_01'] = df.milhar.apply(
    lambda x: int(str(x).zfill(4)[2:])
)

df['resultado_02'] = df.milhar.apply(
    lambda x: int(str(x).zfill(4)[:2])
)

# %%
df['bicho_01'] = df.resultado_01.apply(numero_animal)
df['bicho_02'] = df.resultado_02.apply(numero_animal)

# %%
df['grupo_01'] = df.bicho_01.apply(grupo_animal)
df['grupo_02'] = df.bicho_02.apply(grupo_animal)

# %%
df
# Out:
#             milhar  resultado_01   bicho_01  ...  resultado_02  bicho_02 grupo_02
# data                                         ...
# 2022-09-24    8982            82      Touro  ...            89      Urso       23
# 2022-09-23    6690            90       Urso  ...            66    Macaco       17
# 2022-09-22    8679            79       Peru  ...            86     Tigre       22
# 2022-09-21    5613            13  Borboleta  ...            56      Gato       14
# 2022-09-20    6680            80       Peru  ...            66    Macaco       17
# ...            ...           ...        ...  ...           ...       ...      ...
# 2021-08-12    5452            52       Galo  ...            54      Gato       14
# 2021-07-12     290            90       Urso  ...             2  Avestruz        1
# 2021-06-12    1121            21      Cabra  ...            11     Burro        3
# 2021-04-12    1929            29     Camelo  ...            19  Cachorro        5
# 2021-03-12    3945            45   Elefante  ...            39    Coelho       10
#
# [247 rows x 7 columns]

# %%
from seaborn import set

set()

(df
 .query('bicho_02 == "Galo"')
 .bicho_01
 .groupby(df.bicho_01).count().plot(kind='bar'))
# Out:
# <AxesSubplot: xlabel='bicho_01'>

# %% [markdown]
# # Tabela completa

# %%
from pandas import read_csv

df = read_csv('resultados.csv')

df
# Out:
#             data Prêmio  Milhar  Grupo     Bicho
# 0     24/09/2022     1º    8982     21     Touro
# 1     24/09/2022     2º    9884     21     Touro
# 2     24/09/2022     3º    3231      8    Camelo
# 3     24/09/2022     4º    2156     14      Gato
# 4     24/09/2022     5º    1085     22     Tigre
# ...          ...    ...     ...    ...       ...
# 1230  03/12/2021     1º    3945     12  Elefante
# 1231  03/12/2021     2º    6878     20      Perú
# 1232  03/12/2021     3º    1248     12  Elefante
# 1233  03/12/2021     4º    2200     25      Vaca
# 1234  03/12/2021     5º    2012      3     Burro
#
# [1235 rows x 5 columns]

# %%
df.Prêmio = df.Prêmio.apply(lambda x: int(x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 df.Prêmio = df.Prêmio.apply(lambda x: int(x[0]))
#
# File ~/live_221/.venv/lib/python3.10/site-packages/pandas/core/series.py:4774, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4664 def apply(
#    4665     self,
#    4666     func: AggFuncType,
#    (...)
#    4669     **kwargs,
#    4670 ) -> DataFrame | Series:
#    4671     """
#    4672     Invoke function on values of Series.
#    4673
#    (...)
#    4772     dtype: float64
#    4773     """
# -> 4774     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/live_221/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1100, in SeriesApply.apply(self)
#    1097     return self.apply_str()
#    1099 # self.f is Callable
# -> 1100 return self.apply_standard()
#
# File ~/live_221/.venv/lib/python3.10/site-packages/pandas/core/apply.py:1151, in SeriesApply.apply_standard(self)
#    1149     else:
#    1150         values = obj.astype(object)._values
# -> 1151         mapped = lib.map_infer(
#    1152             values,
#    1153             f,
#    1154             convert=self.convert_dtype,
#    1155         )
#    1157 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1158     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1159     #  See also GH#25959 regarding EA support
#    1160     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/live_221/.venv/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2919, in pandas._libs.lib.map_infer()
#
# Cell In [62], line 1, in <lambda>(x)
# ----> 1 df.Prêmio = df.Prêmio.apply(lambda x: int(x[0]))
#
# TypeError: 'int' object is not subscriptable
