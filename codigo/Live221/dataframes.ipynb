# %% [markdown]
# # Dataframes

# %%
from pandas import DataFrame

d = {
    'Eduardo': [1, 2, 3],
    'Fausto': [4, 5, 6],
    'Tay Turnner': [7, 8, 9],
}

df = DataFrame(d, index=['Idade', 'Peso', 'Quant. Braços'])

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot: >
